# %%
import sys

sys.path.append("..")
from data.preprocessing import load_and_split
from visualize import visualize
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
X_train, X_test, Y_train, Y_test = load_and_split('combined')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: combined
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
reg = LogisticRegression(C=0.01, class_weight={0: 1, 1: 5}, random_state=5)
reg.fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5104
#            1       0.76      0.83      0.80       260
#
#     accuracy                           0.98      5364
#    macro avg       0.88      0.91      0.89      5364
# weighted avg       0.98      0.98      0.98      5364

# %%
visualize(reg, 'combined', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9725
# Average Precision: 0.8669

# %%
X_train, X_test, Y_train, Y_test = load_and_split('text_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: text_only
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
reg = LogisticRegression(C=0.01, class_weight={0: 1, 1: 5}, random_state=5)
reg.fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5104
#            1       0.70      0.79      0.74       260
#
#     accuracy                           0.97      5364
#    macro avg       0.84      0.89      0.86      5364
# weighted avg       0.98      0.97      0.97      5364

# %%
visualize(reg, 'text_only', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9672
# Average Precision: 0.8327

# %%
X_train, X_test, Y_train, Y_test = load_and_split('metadata_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: metadata_only
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
reg = LogisticRegression(C=0.01, class_weight={0: 1, 1: 5}, random_state=5)
reg.fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.77      0.87      5104
#            1       0.16      0.89      0.28       260
#
#     accuracy                           0.77      5364
#    macro avg       0.58      0.83      0.57      5364
# weighted avg       0.95      0.77      0.84      5364

# %%
visualize(reg, 'metadata_only', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9027
# Average Precision: 0.4536
