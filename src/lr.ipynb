# %%
import sys

sys.path.append("..")
from data.preprocessing import load_and_split
from visualize import visualize
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
X_train, X_test, Y_train, Y_test = load_and_split('combined')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: combined
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
reg = LogisticRegression(C=0.01, class_weight={0: 1, 1: 6}, random_state=5)
reg.fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5104
#            1       0.79      0.82      0.81       260
#
#     accuracy                           0.98      5364
#    macro avg       0.89      0.90      0.90      5364
# weighted avg       0.98      0.98      0.98      5364

# %%
visualize(reg, 'combined', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9790
# Average Precision: 0.8807

# %%
X_train, X_test, Y_train, Y_test = load_and_split('text_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: text_only
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
reg = LogisticRegression(C=0.01, class_weight={0: 1, 1: 6}, random_state=5)
reg.fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5104
#            1       0.73      0.81      0.77       260
#
#     accuracy                           0.98      5364
#    macro avg       0.86      0.90      0.88      5364
# weighted avg       0.98      0.98      0.98      5364

# %%
visualize(reg, 'combined', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9732
# Average Precision: 0.8609

# %%
X_train, X_test, Y_train, Y_test = load_and_split('metadata_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: metadata_only
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
reg = LogisticRegression(C=0.01, class_weight={0: 1, 1: 6}, random_state=5)
reg.fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.76      0.86      5104
#            1       0.16      0.89      0.27       260
#
#     accuracy                           0.76      5364
#    macro avg       0.58      0.82      0.56      5364
# weighted avg       0.95      0.76      0.83      5364

# %%
visualize(reg, 'combined', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9022
# Average Precision: 0.4491
