# %% [markdown]
# This notebook provides a basic environment check for the project setup.
# Running successfully confirms that the core data science libraries required for the project have been imported successfully.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

print("Python executable:", sys.executable)
print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("matplotlib:", mpl.__version__)
print("seaborn:", sns.__version__)
print("sklearn:", sklearn.__version__)

x = [1, 2, 3]
y = [1, 4, 9]

plt.plot(x, y)
plt.title("Environment Test Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# The dataset must be present locally for this project to run. Running the following cell confirms that you have the dataset downloaded in the `data` folder:

# %%
from pathlib import Path

proj_root = Path.cwd().parent
data_path = proj_root / "data" / "fake_job_postings.csv"

try:
    df = pd.read_csv(data_path)
    print("=== data loaded successfully ===")
    print(f"Shape: {df.shape}")
    display(df.head())
except FileNotFoundError:
    print(f"error: couldn't find dataset at {data_path}")
    print("run the download script in root")
