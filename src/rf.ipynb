# %%
import pandas as pd
import sys
sys.path.append('..')
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from data.preprocessing import load_and_split

#Build the RF Classifier
#References: https://scikit-learn.org/stable/index.html

def rf_model(feature_type):
    x_train, x_test, y_train, y_test = load_and_split(feature_set=feature_type)
    clf = RandomForestClassifier(n_estimators = 100, random_state = 5) #creates trees
    clf.fit(x_train, y_train) #train model
    y_pred = clf.predict(x_test)
    
    report = classification_report(y_test, y_pred)
    print(report)

# %%
rf_model('metadata_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: metadata_only
# Training samples after SMOTE: 23820
# Test samples: 5364
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      5104
#            1       0.52      0.70      0.60       260
#
#     accuracy                           0.95      5364
#    macro avg       0.75      0.84      0.79      5364
# weighted avg       0.96      0.95      0.96      5364

# %%
rf_model('text_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: text_only
# Training samples after SMOTE: 23820
# Test samples: 5364
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5104
#            1       0.97      0.66      0.78       260
#
#     accuracy                           0.98      5364
#    macro avg       0.98      0.83      0.89      5364
# weighted avg       0.98      0.98      0.98      5364

# %%
rf_model('combined')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: combined
# Training samples after SMOTE: 23820
# Test samples: 5364
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5104
#            1       0.96      0.65      0.78       260
#
#     accuracy                           0.98      5364
#    macro avg       0.97      0.83      0.88      5364
# weighted avg       0.98      0.98      0.98      5364
