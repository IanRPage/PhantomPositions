# %%
import pandas as pd
import sys
sys.path.append('..')
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from data.preprocessing_archive import load_and_split
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
from visualize import visualize

#Build the RF Model
#References: https://scikit-learn.org/stable/index.html

# %% [markdown]
# ## Combined (metadata + text data)

# %%
x_train, x_test, y_train, y_test = load_and_split('combined')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: combined
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
clf = RandomForestClassifier(n_estimators = 200, random_state = 5) #creates trees
clf.fit(x_train, y_train) #train model
y_pred = clf.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5104
#            1       0.97      0.65      0.78       260
#
#     accuracy                           0.98      5364
#    macro avg       0.98      0.82      0.88      5364
# weighted avg       0.98      0.98      0.98      5364

# %%
visualize(clf, 'combined', x_test, y_test, y_pred)
# Out:
# ROC AUC: 0.9876
# Average Precision: 0.9029

# %% [markdown]
# ## Text Only

# %%
x_train, x_test, y_train, y_test = load_and_split('text_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: text_only
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
clf = RandomForestClassifier(n_estimators = 200, random_state = 5) #creates trees
clf.fit(x_train, y_train) #train model
y_pred = clf.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5104
#            1       0.97      0.66      0.78       260
#
#     accuracy                           0.98      5364
#    macro avg       0.98      0.83      0.89      5364
# weighted avg       0.98      0.98      0.98      5364

# %%
visualize(clf, 'text_only', x_test, y_test, y_pred)
# Out:
# ROC AUC: 0.9847
# Average Precision: 0.8882

# %% [markdown]
# ## Metadata Only

# %%
x_train, x_test, y_train, y_test = load_and_split('metadata_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: metadata_only
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
clf = RandomForestClassifier(n_estimators = 200, random_state = 5) #creates trees
clf.fit(x_train, y_train) #train model
y_pred = clf.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      5104
#            1       0.52      0.70      0.60       260
#
#     accuracy                           0.95      5364
#    macro avg       0.75      0.83      0.79      5364
# weighted avg       0.96      0.95      0.96      5364

# %%
visualize(clf, 'metadata_only', x_test, y_test, y_pred)
# Out:
# ROC AUC: 0.9319
# Average Precision: 0.6748
