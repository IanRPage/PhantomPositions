# %%
import sys

sys.path.append("..")
from data.preprocessing import load_and_split
from visualize import visualize


from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

# %% [markdown]
# ## Combined (metadata + text data)

# %%
X_train, X_test, Y_train, Y_test = load_and_split('combined')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: combined
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
svm = LinearSVC(C=0.01, random_state=5)
svm.fit(X_train, Y_train)
Y_pred = svm.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5104
#            1       0.88      0.80      0.84       260
#
#     accuracy                           0.99      5364
#    macro avg       0.94      0.90      0.92      5364
# weighted avg       0.98      0.99      0.98      5364

# %%
visualize(svm, 'combined', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9676
# Average Precision: 0.8685

# %% [markdown]
# ## Text Only

# %%
X_train, X_test, Y_train, Y_test = load_and_split('text_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: text_only
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
svm = LinearSVC(C=0.001, random_state=5)
svm.fit(X_train, Y_train)
Y_pred = svm.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5104
#            1       0.81      0.78      0.79       260
#
#     accuracy                           0.98      5364
#    macro avg       0.90      0.89      0.89      5364
# weighted avg       0.98      0.98      0.98      5364

# %%
visualize(svm, 'text_only', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9654
# Average Precision: 0.8416

# %% [markdown]
# ## Metadata Only

# %%
X_train, X_test, Y_train, Y_test = load_and_split('metadata_only')
# Out:
# === data loaded successfully ===
# Shape: (17880, 18)
# Feature set: metadata_only
# Training samples after SMOTE: 23820
# Test samples: 5364

# %%
svm = LinearSVC(C=0.1, random_state=5)
svm.fit(X_train, Y_train)
Y_pred = svm.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.93      5104
#            1       0.25      0.85      0.39       260
#
#     accuracy                           0.87      5364
#    macro avg       0.62      0.86      0.66      5364
# weighted avg       0.96      0.87      0.90      5364

# %%
visualize(svm, 'metadata_only', X_test, Y_test, Y_pred)
# Out:
# ROC AUC: 0.9059
# Average Precision: 0.4511
