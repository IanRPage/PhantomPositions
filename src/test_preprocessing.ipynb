# %% [markdown]
# ## Preprocessing Validation
#
# This notebook tests the shared preprocessing pipeline to ensure:
# - All feature configurations execute without error
# - Data transformations are applied consistently across models
# - Training data is scaled and resampled correctly (SMOTE)
# - Test data remains untouched (no leakage)

# %%
import sys
sys.path.append('..')
from data.preprocessing import load_and_split

X_train, Y_train, X_test, Y_test = load_and_split(feature_set='metadata_only')
X_train, Y_train, X_test, Y_test = load_and_split(feature_set='text_only')
X_train, Y_train, X_test, Y_test = load_and_split(feature_set='combined')
